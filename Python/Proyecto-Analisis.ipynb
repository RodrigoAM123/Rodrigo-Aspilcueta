# %%
import pandas as pd 

videojuegos = pd.read_csv("videogamessales.csv", sep=';')
videojuegos
# Out:
#                                                Name Platform    Year  \
# 0                                   The Bard's Tale       XB  2004.0
# 1                                          Polarium       DS  2004.0
# 2                                                N+       DS  2007.0
# 3                    SingStar Singalong With Disney      PS2  2008.0
# 4      Teenage Mutant Ninja Turtles 2: Battle Nexus      GBA  2004.0
# ...                                             ...      ...     ...
# 16322                               Resident Evil 6      PS3  2012.0
# 16323                            SingStar Pop Vol.2      PS2  2008.0
# 16324                                   Army of Two      PS3  2008.0
# 16325                          Train Simulator 2016       PC  2015.0
# 16326             NPPL: Championship Paintball 2009      PS3  2008.0
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
videojuegos.info()
#Como se ve la columna "yEAR" tiene como tipo de dato: decimal o float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16327 entries, 0 to 16326
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16327 non-null  object
#  1   Platform     16327 non-null  object
#  2   Year         16327 non-null  float64
#  3   Genre        16327 non-null  object
#  4   Publisher    16291 non-null  object
#  5   NA_Sales     16327 non-null  float64
#  6   EU_Sales     16327 non-null  float64
#  7   JP_Sales     16327 non-null  float64
#  8   Other_Sales  16327 non-null  float64
# dtypes: float64(5), object(4)
# memory usage: 1.1+ MB

# %%
videojuegos["Year"]=videojuegos["Year"].astype(int)
videojuegos.head(5)
#Con esto cambiamos de FLOAT a int.
# Out:
#                                            Name Platform  Year         Genre  \
# 0                               The Bard's Tale       XB  2004  Role-Playing
# 1                                      Polarium       DS  2004        Puzzle
# 2                                            N+       DS  2007      Platform
# 3                SingStar Singalong With Disney      PS2  2008          Misc
# 4  Teenage Mutant Ninja Turtles 2: Battle Nexus      GBA  2004        Action
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0                       Ubisoft      0.08      0.02      0.00         0.00
# 1                      Nintendo      0.13      0.01      0.11         0.01
# 2                         Atari      0.06      0.00      0.00         0.00
# 3   Sony Computer Entertainment      0.00      0.04      0.00         0.57
# 4  Konami Digital Entertainment      0.23      0.09      0.00         0.01

# %%
videojuegos = videojuegos.rename(columns={
    'Name': 'Nombre',
    'Platform': 'Plataforma',
    'Year': 'Año',
    'Genre': 'Género',
    'Publisher': 'Distribuidor',
    'NA_Sales': 'Ventas_NA',
    'EU_Sales': 'Ventas_EU',
    'JP_Sales': 'Ventas_JP',
    'Other_Sales': 'Ventas_Otros'
})
videojuegos.head(1)
#Acá solo traduje los nombres de cada columna
# Out:
#             Nombre Plataforma   Año        Género Distribuidor  Ventas_NA  \
# 0  The Bard's Tale         XB  2004  Role-Playing      Ubisoft       0.08
#
#    Ventas_EU  Ventas_JP  Ventas_Otros
# 0       0.02        0.0           0.0

# %%
videojuegos['Ventas_Globales'] = videojuegos['Ventas_NA'] + videojuegos['Ventas_EU'] + videojuegos['Ventas_JP'] + videojuegos['Ventas_Otros']
videojuegos.head(5)
# Out:
#                                          Nombre Plataforma   Año  \
# 0                               The Bard's Tale         XB  2004
# 1                                      Polarium         DS  2004
# 2                                            N+         DS  2007
# 3                SingStar Singalong With Disney        PS2  2008
# 4  Teenage Mutant Ninja Turtles 2: Battle Nexus        GBA  2004
#
#          Género                  Distribuidor  Ventas_NA  Ventas_EU  \
# 0  Role-Playing                       Ubisoft       0.08       0.02
# 1        Puzzle                      Nintendo       0.13       0.01
# 2      Platform                         Atari       0.06       0.00
# 3          Misc   Sony Computer Entertainment       0.00       0.04
# 4        Action  Konami Digital Entertainment       0.23       0.09
#
#    Ventas_JP  Ventas_Otros  Ventas_Globales
# 0       0.00          0.00             0.10
# 1       0.11          0.01             0.26
# ...

# %%
videojuegos = videojuegos.sort_values(by='Ventas_Globales', ascending=False)
videojuegos['Ranking'] = range(1, len(videojuegos) + 1) 
videojuegos
#Ordene y agregé el ranking para conocer que videojuego ganó más.
# Out:
#                                                  Nombre Plataforma   Año  \
# 2680                                         Wii Sports        Wii  2006
# 6553                                  Super Mario Bros.        NES  1985
# 10016                                    Mario Kart Wii        Wii  2008
# 15776                                 Wii Sports Resort        Wii  2009
# 15702                          Pokemon Red/Pokemon Blue         GB  1996
# ...                                                 ...        ...   ...
# 116          Wedding Planner: Dream Weddings Guaranteed         DS  2010
# 112                                   Act of Aggression         PC  2015
# 125                              Battlestations: Midway         PC  2007
# 12483                       Winning Post 7 Maximum 2008        PS3  2008
# 3587   SCORE International Baja 1000: The Official Game        PS2  2008
#
#              Género            Distribuidor  Ventas_NA  Ventas_EU  Ventas_JP  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10 = videojuegos.head(10)  # Selecciona el top 10

plt.figure(figsize=(12, 6))
sns.barplot(x='Ventas_Globales', y='Nombre', data=top_10, palette='viridis')

plt.xlabel('Ventas Globales (millones)')
plt.ylabel('Juego')
plt.title('Top 10 Juegos Más Vendidos')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18484\109258223.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Ventas_Globales', y='Nombre', data=top_10, palette='viridis')

# %%
ventas_por_genero = videojuegos.groupby('Género')['Ventas_Globales'].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 8))
ventas_por_genero.head(5).plot(kind='pie', autopct='%1.1f%%', startangle=90, colormap='Set2')

plt.title('Ventas globales por género (Top 5)')
plt.ylabel('')
plt.show()

# %%
ventas_por_plataforma = videojuegos.groupby('Plataforma')['Ventas_Globales'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
ventas_por_plataforma.plot(kind='bar', color='skyblue')

plt.xlabel('Plataforma')
plt.ylabel('Ventas globales (millones)')
plt.title('Ventas globales por plataforma')
plt.xticks(rotation=45)
plt.show()
#Acá se da a entender que la PS2 es la reina en ventas globales.

# %%
ventas_por_año = videojuegos.groupby('Año')['Ventas_Globales'].sum()

plt.figure(figsize=(12, 6))
plt.plot(ventas_por_año.index, ventas_por_año.values, marker='o', linestyle='-', color='red')

plt.xlabel('Año')
plt.ylabel('Ventas globales (millones)')
plt.title('Evolución de ventas de videojuegos')
plt.grid(True)
plt.show()

#Acá un punto aparte porque estas ventas son con productos físicos y no digitales. Y hay que recalcar que el mercado digital supero por
#mucho el mercado físico.
